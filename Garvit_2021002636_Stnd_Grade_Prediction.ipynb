# %% [markdown]
# <a href="https://colab.research.google.com/github/Garvit2911/Bootcamp_DataScience/blob/main/Garvit_2021002636_Stnd_Grade_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/original.csv')
df.head()
# Out:
#    Gender   Age  POLAR4 Quintile  POLAR3 Quintile  Adult HE 2001 Quintile  \
# 0     0.0  38.0              5.0              5.0                     4.0
# 1     0.0  22.0              4.0              2.0                     1.0
# 2     0.0  21.0              4.0              5.0                     4.0
# 3     0.0  25.0              5.0              4.0                     3.0
# 4     0.0  20.0              5.0              4.0                     3.0
#
#    Adult HE 2011 Quintile  TUNDRA MSOA Quintile  TUNDRA LSOA Quintile  \
# 0                     5.0                   4.0                   4.0
# 1                     3.0                   4.0                   4.0
# 2                     5.0                   4.0                   4.0
# 3                     4.0                   3.0                   3.0
# 4                     4.0                   3.0                   3.0
#
#    Gaps GCSE Quintile   Gaps GCSE Ethnicity Quintile  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Gender                             80 non-null     float64
#  1   Age                                80 non-null     float64
#  2   POLAR4 Quintile                    80 non-null     float64
#  3   POLAR3 Quintile                    80 non-null     float64
#  4   Adult HE 2001 Quintile             80 non-null     float64
#  5   Adult HE 2011 Quintile             80 non-null     float64
#  6   TUNDRA MSOA Quintile               80 non-null     float64
#  7   TUNDRA LSOA Quintile               80 non-null     float64
#  8   Gaps GCSE Quintile                 80 non-null     float64
#  9   Gaps GCSE Ethnicity Quintile       80 non-null     float64
#  10  Uni Connect target ward            80 non-null     float64
# ...

# %%
df.shape
# Out:
# (87, 22)

# %%
df = df.drop(['Unnamed: 20', 'Unnamed: 21'], axis=1)
df.head()
# Out:
#    Gender   Age  POLAR4 Quintile  POLAR3 Quintile  Adult HE 2001 Quintile  \
# 0     0.0  38.0              5.0              5.0                     4.0
# 1     0.0  22.0              4.0              2.0                     1.0
# 2     0.0  21.0              4.0              5.0                     4.0
# 3     0.0  25.0              5.0              4.0                     3.0
# 4     0.0  20.0              5.0              4.0                     3.0
#
#    Adult HE 2011 Quintile  TUNDRA MSOA Quintile  TUNDRA LSOA Quintile  \
# 0                     5.0                   4.0                   4.0
# 1                     3.0                   4.0                   4.0
# 2                     5.0                   4.0                   4.0
# 3                     4.0                   3.0                   3.0
# 4                     4.0                   3.0                   3.0
#
#    Gaps GCSE Quintile   Gaps GCSE Ethnicity Quintile  Uni Connect target ward  \
# ...

# %%
df.shape
# Out:
# (87, 20)

# %%
df1 = df.dropna()

# %%
X = df1.iloc[:,:-1]
y = df1.iloc[:,-1]

# %%
X.head()
# Out:
#    Gender   Age  POLAR4 Quintile  POLAR3 Quintile  Adult HE 2001 Quintile  \
# 0     0.0  38.0              5.0              5.0                     4.0
# 1     0.0  22.0              4.0              2.0                     1.0
# 2     0.0  21.0              4.0              5.0                     4.0
# 3     0.0  25.0              5.0              4.0                     3.0
# 4     0.0  20.0              5.0              4.0                     3.0
#
#    Adult HE 2011 Quintile  TUNDRA MSOA Quintile  TUNDRA LSOA Quintile  \
# 0                     5.0                   4.0                   4.0
# 1                     3.0                   4.0                   4.0
# 2                     5.0                   4.0                   4.0
# 3                     4.0                   3.0                   3.0
# 4                     4.0                   3.0                   3.0
#
#    Gaps GCSE Quintile   Gaps GCSE Ethnicity Quintile  Uni Connect target ward  \
# ...

# %%
y.head()
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: label (fail=1, pass=0), dtype: float64

# %%
# mode_value = X['# of Absence'].mode()
# X['# of Absence'].fillna(value=mode_value, inplace=True)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78 entries, 0 to 79
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Gender                             78 non-null     float64
#  1   Age                                78 non-null     float64
#  2   POLAR4 Quintile                    78 non-null     float64
#  3   POLAR3 Quintile                    78 non-null     float64
#  4   Adult HE 2001 Quintile             78 non-null     float64
#  5   Adult HE 2011 Quintile             78 non-null     float64
#  6   TUNDRA MSOA Quintile               78 non-null     float64
#  7   TUNDRA LSOA Quintile               78 non-null     float64
#  8   Gaps GCSE Quintile                 78 non-null     float64
#  9   Gaps GCSE Ethnicity Quintile       78 non-null     float64
#  10  Uni Connect target ward            78 non-null     float64
# ...

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 78 entries, 0 to 79
# Series name: label (fail=1, pass=0)
# Non-Null Count  Dtype
# --------------  -----
# 78 non-null     float64
# dtypes: float64(1)
# memory usage: 1.2 KB

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

# %%
rf.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
test = pd.read_csv('/content/test.csv')
test.head()
# Out:
#    Gender  Age  POLAR4 Quintile  POLAR3 Quintile  Adult HE 2001 Quintile  \
# 0       0   30                5                5                       5
# 1       0   24                2                2                       1
# 2       0   21                3                3                       2
# 3       0   21                3                2                       2
# 4       0   21                4                5                       5
#
#    Adult HE 2011 Quintile  TUNDRA MSOA Quintile  TUNDRA LSOA Quintile  \
# 0                       0                     4                     4
# 1                       2                     1                     1
# 2                       3                     2                     2
# 3                       2                     2                     2
# 4                       5                     5                     5
#
#    Gaps GCSE Quintile   Gaps GCSE Ethnicity Quintile  Uni Connect target ward  \
# ...

# %%
test.shape
# Out:
# (80, 20)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Gender                             80 non-null     int64
#  1   Age                                80 non-null     int64
#  2   POLAR4 Quintile                    80 non-null     int64
#  3   POLAR3 Quintile                    80 non-null     int64
#  4   Adult HE 2001 Quintile             80 non-null     int64
#  5   Adult HE 2011 Quintile             80 non-null     int64
#  6   TUNDRA MSOA Quintile               80 non-null     int64
#  7   TUNDRA LSOA Quintile               80 non-null     int64
#  8   Gaps GCSE Quintile                 80 non-null     int64
#  9   Gaps GCSE Ethnicity Quintile       80 non-null     int64
#  10  Uni Connect target ward            80 non-null     int64
# ...

# %%
test = test.dropna()

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76 entries, 1 to 79
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Gender                             76 non-null     int64
#  1   Age                                76 non-null     int64
#  2   POLAR4 Quintile                    76 non-null     int64
#  3   POLAR3 Quintile                    76 non-null     int64
#  4   Adult HE 2001 Quintile             76 non-null     int64
#  5   Adult HE 2011 Quintile             76 non-null     int64
#  6   TUNDRA MSOA Quintile               76 non-null     int64
#  7   TUNDRA LSOA Quintile               76 non-null     int64
#  8   Gaps GCSE Quintile                 76 non-null     int64
#  9   Gaps GCSE Ethnicity Quintile       76 non-null     int64
#  10  Uni Connect target ward            76 non-null     int64
#  11  attending from home?               76 non-null     int64
# ...

# %%
y_test = test['label (fail=1, pass=0)']

# %%
x_test = test.iloc[:,:-1]
x_test.head()
# Out:
#    Gender  Age  POLAR4 Quintile  POLAR3 Quintile  Adult HE 2001 Quintile  \
# 1       0   24                2                2                       1
# 2       0   21                3                3                       2
# 3       0   21                3                2                       2
# 5       0   32                1                1                       1
# 6       0   20                4                4                       4
#
#    Adult HE 2011 Quintile  TUNDRA MSOA Quintile  TUNDRA LSOA Quintile  \
# 1                       2                     1                     1
# 2                       3                     2                     2
# 3                       2                     2                     2
# 5                       1                     1                     1
# 6                       3                     3                     3
#
#    Gaps GCSE Quintile   Gaps GCSE Ethnicity Quintile  Uni Connect target ward  \
# ...

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96        67
#            1       0.83      0.56      0.67         9
#
#     accuracy                           0.93        76
#    macro avg       0.89      0.77      0.82        76
# weighted avg       0.93      0.93      0.93        76
